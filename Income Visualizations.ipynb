# %%
# conda install -c conda-forge rise

# Use this to create slide-view in a notebook?

# %%
library('tidyverse')

Income = read_csv('https://raw.githubusercontent.com/rcjones9/Budget/main/JVG_df.csv', col_types = cols()) |>
    select(Role, Month, Date, Day, Shift, Time, Rate, Tips, Total)

head(Income)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# New names:
# • `` -> `...12`
# • `` -> `...13`
# • `` -> `...14`
# • `` -> `...15`
# • `` -> `...16`
#   Role     Month Date    Day       Shift Time  Rate  Tips Total
# 1 Training March 3/22/22 Tuesday   Open   67.2  9.75 0    10.92
# 2 Training March 3/25/22 Friday    Close 240.0  9.75 0    39.00
# 3 Training March 3/26/22 Saturday  N/A   349.8 10.50 0    61.22
# 4 Training March 3/28/22 Monday    Open  279.0 10.50 0    48.83
# 5 Training March 3/30/22 Wednesday Open  186.6 10.50 0    32.66
# 6 Training March 3/31/22 Thursday  N/A   195.0 10.50 0    34.13

# %%
options( repr.plot.width = 5, repr.plot.height = 3, repr.plot.res = 300)

Income |>
    group_by(Shift) |>
    summarize(N = n()) |>
    arrange(desc(N))

p3 = ggplot(Income, aes(x=Shift)) +
    geom_bar() +
    labs(title = "Amount of working each type of shift", x = "Type of Shift", y = "Number of Shifts") +
    theme_minimal()
p3
# Out:
#   Shift   N
# 1 Open    57
# 2 Close   48
# 3 N/A     27
# 4 Mid     15
# 5 Baker 1  1
# plot without title

# %% [markdown]
# ## I have not worked very many mid shifts! Mostly opening.

# %%
options(repr.plot.width=5, repr.plot.height=4, repr.plot.res = 350)

Income_week = Income |>
    mutate( Day_sorted = Day |> 
           fct_relevel('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday')
          )

p = ggplot(Income_week, aes(x=Day_sorted)) +
    theme_classic() +
    geom_bar(fill = 'green') +
    labs(title = "Total $ Made on Each Day of the Week", x = "Day of the Week", y = "Total $ Earned") +
    scale_y_continuous(labels = scales::dollar)


p
# Out:
# plot without title

# %% [markdown]
# ## I have worked more on the weekends, so this is less accurate than averaged tips earned!

# %%
options( repr.plot.width = 10, repr.plot.height = 4, repr.plot.res = 500)

# Income_Ordered = Income |>

p2 = ggplot(Income, aes(x = Day, y = Total, color = Shift)) +
    geom_point(position = position_jitter(w=0.2, h=0), alpha=0.6, size=3) +
    labs(title = "Total $ Made on Each Day of the Week", x = "Day of the Week", y = "Total $ Earned", color = "Type of Shift") +
    scale_y_continuous(labels = scales::dollar) +
    theme_minimal()

p2
# Out:
# plot without title

# %% [markdown]
# ## I have made the most money on weekend opening shifts, but the few mid shifts that I have done were very lucrative too.

# %%
Income_days = Income |>
    group_by(Day) |>
    summarize(N = n()) |>
    arrange(desc(N))

Income_days
# Out:
#   Day       N
# 1 Friday    35
# 2 Sunday    31
# 3 Tuesday   26
# 4 Monday    23
# 5 Saturday  21
# 6 Wednesday  7
# 7 Thursday   5

# %%
options( repr.plot.width = 9, repr.plot.height = 4, repr.plot.res = 300)

avg_tips = Income |>
    group_by(Shift) |>
    summarize( Tips = mean(Tips))

p4 = ggplot( data = avg_tips, aes(x = Shift, y= Tips, label = Tips)) +
    geom_col(na.rm = FALSE, fill = "black") +
    geom_text(color = 'white', vjust = 1.4, size = 4) +
    labs(title = "Average Tips Based on Shift", x = "Type of Shift", y = "Tips ($)")


p4
# Out:
# plot without title

# %% [markdown]
# ## This is proof that I have made more money during mid shifts than opening or closing! Go midshifts. Boo closing.
